# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import os
import chardet

# %%
os.chdir('../01b_Analisis de datos//')
nomArch = 'whisky.csv' 
with open(nomArch, 'rb') as f:
    result = chardet.detect(f.read())  # or readline if the file is large

df= pd.read_csv(nomArch, encoding=result['encoding'])


#--Matriz de correlacion --
print(df.corr())

sns.heatmap(df.corr(), square=True, annot=True)

plt.figure()
# Out:
#              id_Whisky    Precio     Malta  Añejamiento   Calidad
# id_Whisky     1.000000  0.694234  0.827269     0.563860  0.333163
# Precio        0.694234  1.000000  0.699957     0.512761  0.297712
# Malta         0.827269  0.699957  1.000000     0.379150  0.241101
# Añejamiento   0.563860  0.512761  0.379150     1.000000  0.275765
# Calidad       0.333163  0.297712  0.241101     0.275765  1.000000
